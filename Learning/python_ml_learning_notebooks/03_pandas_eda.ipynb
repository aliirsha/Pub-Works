# %% [markdown]
# # Pandas & EDA
# DataFrames, filtering, missing values, summary stats.

# %%
# install pandas if it is not there in your system
# pip install pandas
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 25.9 MB/s  0:00:00m0:00:010:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# Sample DataFrame
data = {'A': [1, 2, None], 'B': ['x', 'y', 'z']}
df = pd.DataFrame(data)
print(df.describe(include='all'))
print(df.isnull().sum())
# Out:
#                A    B
# count   2.000000    3
# unique       NaN    3
# top          NaN    x
# freq         NaN    1
# mean    1.500000  NaN
# std     0.707107  NaN
# min     1.000000  NaN
# 25%     1.250000  NaN
# 50%     1.500000  NaN
# 75%     1.750000  NaN
# max     2.000000  NaN
# A    1
# B    0
# dtype: int64

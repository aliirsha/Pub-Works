# %%
import numpy as np

# %%
product_prices = [100,500, 3000, 2000]
prod_array = np.array(product_prices)

prod_disc_amount = prod_array * 0.05
print(prod_disc_amount)
# Out:
# [  5.  25. 150. 100.]

# %%
prod_price_after_disc = prod_array - prod_disc_amount
print(prod_price_after_disc)
# Out:
# [  95.  475. 2850. 1900.]
